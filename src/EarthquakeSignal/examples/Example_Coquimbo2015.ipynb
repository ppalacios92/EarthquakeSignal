# %%
from EarthquakeSignal import EarthquakeBatchProcessor
from LadrunoGraphStyle import set_default_plot_params
set_default_plot_params()

# %%
# pip list

# %% [markdown]
# ### Set config manual

# %%
config = {
    'file_extension': '.txt',
    'unit_factor': 9.81,
    
    'apply_baseline_correction': True,
    'apply_arias_analysis': True,
    'apply_fourier_analysis': True,
    '_compute_newmark_spectra': True,
    'compute_rotd': False,
    'print_summary': True,
    
    'plot_signals': True,
    'plot_corrected_signals': False,
    'plot_arias_signals': False,
    'plot_fourier_signals': False,  
    'plot_newmark_spectra': True,
    'plot_rotd': False,
}

# %%
registers_path = r'data\Coquimbo2015'

# %%
processor = EarthquakeBatchProcessor(registers_path, config)
earthquake = processor.process_all()
# Out:
# Processing earthquakes: 0it [00:00, ?it/s]

# %% [markdown]
# ### For each earthquake

# %%
# earthquake['APED'].print_summary()
# earthquake['APED'].plot_original_signals()
# earthquake['APED'].plot_corrected_signals()
# earthquake['APED'].plot_arias_signals()
# earthquake['APED'].plot_fourier_signals()
# earthquake['APED'].plot_newmark_spectra()

# %%
record = earthquake['AC04']


print("🔹 Arias Intensity")
print(f"Significant Duration Start  : {record.arias['H1']['t_start']:.3f} s")
print(f"Significant Duration End    : {record.arias['H1']['t_end']:.3f} s")
print(f"Total Arias Intensity       : {record.arias['H1']['IA_total']:.5f} m/s")
print(f"Destructive Potential Index : {record.arias['H1']['pot_dest']:.5f}")


print("\n🔹 Fourier Analysis")
print("Dominant Periods (s):", record.fourier['H1']['dominant_periods'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 record = earthquake['AC04']
#       4 print("🔹 Arias Intensity")
#       5 print(f"Significant Duration Start  : {record.arias['H1']['t_start']:.3f} s")
#
# KeyError: 'AC04'

# %% [markdown]
# ## Keys and Methods

# %%
first_key = next(iter(earthquake))
eq = earthquake[first_key]

print("Keys:")
for key in vars(eq):
    print(f"  - {key}")

print("\nMethods:")
import inspect
methods = [name for name, obj in inspect.getmembers(eq, inspect.ismethod) if not name.startswith('_')]
for m in methods:
    print(f"  - {m}()")
# Out:
# Keys:
#   - filepath
#   - config
#   - name
#   - dt
#   - signals
#   - component_names
#   - corrected_acc
#   - corrected_vel
#   - corrected_disp
#   - arias
#   - newmark_spectra
#   - rotd
#   - fourier
#   - summary_tool
#   - plotter_tool
#   - comparison_tool
#   - arias_plotter
#   - fourier_plotter
#   - newmark_plotter
#   - rotd_plotter
#   - signals_raw
#
# Methods:
#   - load_and_process()
#   - plot_arias_signals()
#   - plot_corrected_signals()
#   - plot_fourier_signals()
#   - plot_newmark_spectra()
#   - plot_original_signals()
#   - plot_rotd()
#   - print_summary()

# %% [markdown]
# ### All spectra

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# --- Calcular ruta correcta ---
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
output_dir = os.path.join(project_root, 'outputs')
os.makedirs(output_dir, exist_ok=True)
svg_path = os.path.join(output_dir, "all _records_coquimbo2015.svg")

# --- Graficar espectros ---
plt.figure(figsize=(14, 4))

# Subplot para H1
plt.subplot(1, 2, 1)
for rsn, eq in earthquake.items():
    try:
        T_H1 = eq.newmark_spectra['H1']['T']
        PSa_H1 = eq.newmark_spectra['H1']['PSa']
        plt.plot(T_H1, PSa_H1, linewidth=1.5, label=f"{rsn}")
    except KeyError:
        print(f"Warning: {rsn} missing H1 spectrum")

plt.title("Component H1", fontsize=10, fontweight='bold')
plt.xlabel("Period [s]", fontsize=9, fontweight='bold')
plt.ylabel("PSa [g]", fontsize=9, fontweight='bold')
plt.grid(True, which='both')
plt.xlim(left=0, right=5)
plt.tick_params(axis='both', labelsize=8)
plt.legend(fontsize=7, loc='upper right', ncol=2)

# Subplot para H2
plt.subplot(1, 2, 2)
for rsn, eq in earthquake.items():
    try:
        T_H2 = eq.newmark_spectra['H2']['T']
        PSa_H2 = eq.newmark_spectra['H2']['PSa']
        plt.plot(T_H2, PSa_H2, linewidth=1.5, label=f"{rsn}")
    except KeyError:
        print(f"Warning: {rsn} missing H2 spectrum")

plt.title("Component H2", fontsize=10, fontweight='bold')
plt.xlabel("Period [s]", fontsize=9, fontweight='bold')
plt.ylabel("PSa [g]", fontsize=9, fontweight='bold')
plt.grid(True, which='both')
plt.xlim(left=0, right=5)
plt.tick_params(axis='both', labelsize=8)
plt.legend(fontsize=7, loc='upper right', ncol=2)

plt.suptitle("All Records Coquimbo2015", fontsize=11, fontweight='bold')

# --- Guardar como SVG en outputs/
plt.savefig(svg_path, format='svg')
plt.show()

# %% [markdown]
# ### Rotd100

# %%
# Create figure with 1 row and 1 column
plt.figure(figsize=(7, 4))

# Subplot for ROTD100
plt.subplot(1, 1, 1)
for rsn, eq in earthquake.items():
    try:

        T = eq.rotd['T']
        PSa_rotd100 = eq.rotd['ROTD100']
        pga = round(PSa_rotd100[0], 3)
        plt.plot(T, PSa_rotd100, linewidth=1.5, label=f"{rsn} -PGA:{pga} g")
    except KeyError:
        print(f"Warning: {rsn} missing ROTD100 spectrum")

plt.title("ROTD100 - All Records", fontsize=10, fontweight='bold')
plt.xlabel("Period [s]", fontsize=9, fontweight='bold')
plt.ylabel("PSa [g]", fontsize=9, fontweight='bold')
plt.grid(True, which='both')
plt.xlim(left=0, right=5)
plt.tick_params(axis='both', labelsize=8)
plt.legend(fontsize=7, loc='upper right', ncol=2)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Warning: AC04 missing ROTD100 spectrum
# Warning: C01O missing ROTD100 spectrum
# Warning: C09O missing ROTD100 spectrum
# Warning: C10O missing ROTD100 spectrum
# Warning: C11O missing ROTD100 spectrum
# Warning: C14O missing ROTD100 spectrum
# Warning: C18O missing ROTD100 spectrum
# Warning: C20O missing ROTD100 spectrum
# Warning: C22O missing ROTD100 spectrum
# Warning: C23O missing ROTD100 spectrum
# Warning: C26O missing ROTD100 spectrum
# Warning: C27O missing ROTD100 spectrum
# Warning: C28O missing ROTD100 spectrum
# Warning: C32O missing ROTD100 spectrum
# Warning: C33O missing ROTD100 spectrum
# Warning: CO03 missing ROTD100 spectrum
# Warning: CO06 missing ROTD100 spectrum
# Warning: GO04 missing ROTD100 spectrum
# Warning: LMEL missing ROTD100 spectrum
# Warning: M02L missing ROTD100 spectrum
# Warning: M03L missing ROTD100 spectrum
# Warning: M09L missing ROTD100 spectrum
# Warning: M11L missing ROTD100 spectrum
# Warning: M13L missing ROTD100 spectrum
# Warning: MT01 missing ROTD100 spectrum
# Warning: MT05 missing ROTD100 spectrum
# Warning: MT09 missing ROTD100 spectrum
# Warning: R02M missing ROTD100 spectrum
# Warning: R05M missing ROTD100 spectrum
# Warning: R12M missing ROTD100 spectrum
# Warning: R13M missing ROTD100 spectrum
# Warning: R14M missing ROTD100 spectrum
# Warning: R16M missing ROTD100 spectrum
# Warning: R18M missing ROTD100 spectrum
# Warning: R19M missing ROTD100 spectrum
# Warning: R20M missing ROTD100 spectrum
# Warning: R21M missing ROTD100 spectrum
# Warning: R22M missing ROTD100 spectrum
# Warning: R23M missing ROTD100 spectrum
# Warning: ROC1 missing ROTD100 spectrum
# Warning: V01A missing ROTD100 spectrum
# Warning: V02A missing ROTD100 spectrum
# Warning: V07A missing ROTD100 spectrum
# Warning: V09A missing ROTD100 spectrum
# Warning: V15A missing ROTD100 spectrum
# Warning: V16A missing ROTD100 spectrum
# Warning: V17A missing ROTD100 spectrum
# Warning: V22A missing ROTD100 spectrum
# Warning: V24A missing ROTD100 spectrum
# Warning: VA01 missing ROTD100 spectrum
# Warning: VA03 missing ROTD100 spectrum
# Warning: VA05 missing ROTD100 spectrum
# Warning: VA06 missing ROTD100 spectrum
